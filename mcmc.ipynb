# %%
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline


qaly = np.array([13, 14, -14, 12, 9, 15, 10, 14, 9, 14, -13, 12, 9, 10, 15, 11, 
                15, 11, 7, 13, 13, 10, 9, 6, 11, 15, -13, 10, 9, -9, 15, 14, 
                14, 10, 14, 11, 13, 14, 10])
cost = np.array([-2950, 2300, 3900, -2800, 5000, 2999, 3950, 2995, 4500, 2800, 
                  1990, 3500, 5100, 3900, 2900, -4950, 2000, 3400, 8999, 4000, 
                  2950, 3250, 3950, 4600, 4500, 1600, 3900, -4200, 6500, 3500, 
                  2999, 2600, 3250, 2500, 2400, 3990, 4600, 450,4700])/1000.


sb.scatterplot(qaly, cost)
plt.xlabel('Effectiveness (QALY)')
plt.ylabel('Cost');

# %%
import pymc3 as pm

with pm.Model():
    # Prior distributions for latent variables
    alpha = pm.Normal('alpha', 0, sd=100)
    beta = pm.Triangular('beta')
    # x = pm.Normal('x', mu=10, sigma=10)

    # Draw samples
    # trace = pm.sample()
    trace = pm.sample(draws=10000)

    # Plot two parameters
    pm.plots.traceplot(trace, var_names=['alpha', 'beta'])
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='44000' class='' max='44000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [44000/44000 00:06<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 10_000 draw iterations (4_000 + 40_000 draws total) took 14 seconds.
